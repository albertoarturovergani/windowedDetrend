# %% [markdown]
# # pars

# %%
from tmspath_utils import *

# %%
date, start_time = import_modules()

detrendType = 'Non-Windowed'

if detrendType == 'Non-Windowed':
    typeOffsetRise, typeOffsetDecay = 'nowind_biexp', 'nowind_biexp'
if detrendType == 'Windowed':
    typeOffsetRise = 'wind_poly_lagrange' #'wind_singlerise',
    typeOffsetDecay = 'wind_poly_3' # 'wind_poly_0', 'wind_poly_1', 'wind_poly_2', 'wind_singledecay',
if detrendType == 'ICA_Detrend':
    typeOffsetRise = 'ICA' 
    typeOffsetDecay = 'ICA' 
    
# === Config iniziale ===
json_data = {
    'date': date,
    'start_time': start_time,
    'showPlotsEnd': False,
    'l_freq': 0.1,
    'h_freq': 45,
    'powerline_freq': 50,
    'broad_band_h_freq': 250,

    'do_pulseArtifactRej': True,
    'do_filter_and_plot_raw': True,
    'do_clean_trials_channels': True,
    'do_prepare_epochs': True,
    'detrendExtremeTechinque': 'max',
    'epochs_timewindow_min': -0.1,
    'epochs_timewindow_max': 0.4,
    'baseline_cor_tmin': -0.15,
    'baseline_cor_tmax': 0,
    'r_sfreq': 1024,
    'do_chan_trials_selection_automatic': True,

    'do_artifact': False, 
    'do_artifact_rise': 0.005,
    'do_artifact_decay': 0.1,
    'do_artifact_gain': -3e-6 * 30,

    'do_ica': False, # if typeOffsetDecay == typeOffsetRise == 'ICA' make True else no detrend at all
    'do_ica_continuum': False,
    'do_ica_manualCheck': False, 
    'do_ica_eigThresh': 0,
    'do_ica_automaticRej': True,
    'do_label_prob_threshold': 0,

    'detrend_type': typeOffsetDecay,
    'do_detrend': typeOffsetDecay != 'ICA',
    'do_detrend_onlyOffsetChans': False,
    'detrend_offsetStart': True,
    'detrend_lag_correction': False,
    'detrend_typeOffsetRise': typeOffsetRise,
    'detrend_typeOffsetDecay': typeOffsetDecay,
    'detrend_polOrder_preOffset': 2,
    'detrend_slopeThr': 0.5, # 0.5, # important for making the detrend otherwise skip to poly0 without windowing (demeaning)
                            # e.g. suggestion: start with 10/15 for not doing detrend, than use an appropriate threshold from 2.detrend slope plot
                            # the slope evaluation is itself a windowed approach, but different from detrending, so csv generated have tags "offset, pre, post" as detrend
    'detrend_offsetCorrectionType': 'Gaussian' if 'nowind' not in typeOffsetDecay else False,
    'detrend_offsetOddSamples': 5,
    'detrend_overall': True,
    'detrend_noWindowedOrder': 0,
    'detrend_maxTimeWindowOffset': 0.020,
    'detrend_minTimeWindowOffset': 0.0,
    'detrend_fitConstraint': False if 'nowind' not in typeOffsetDecay else True,

    'sourceData': 'UNIMI', #'Chalfont', #'UNIMI', # MAYER CHALFONT
    'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\Chalfont\CE20_07_08_2019_Session_4_LPrem_77\\",
    'subject': "prova_Mario_0003", #"CE20_07_08_2019_000004", #"prova_Mario_0003",
    'dataType': 'VHDR',
    'emispheric_stimulation': 'CX',
    'seedChans': ['Cz', 'C3'], # 'SX': ['AF3', 'F3', 'Fz', 'FC1'], 'DX': ['Fz', 'AF4', 'F4', 'FC2'],
}

mainDir = json_data['mainDir']
subject = json_data['subject']
experiment_dir_ = f'{mainDir}{subject}'
fileName = f'{mainDir}{subject}'
savePath = f'{mainDir}{subject}'
json_data['analysis_id'] = f'{date}_{subject}'

print(fileName)
# Out:
# E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\\prova_Mario_0003

# %% [raw]
# # === Dataset specifici ===
# if sub == 'ChalfontCE20':
#     json_data.update({
#         'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\Chalfont\CE20_07_08_2019_Session_4_LPrem_77\\",
#         'subject': "CE20_07_08_2019_000004",
#         'dataType': 'VHDR',
#         'emispheric_stimulation': 'CX',
#     })
#
# elif sub == 'ChalfontCE17':
#     json_data.update({
#         'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\Chalfont\CE17_18_07_2019_Session_3_RMot_41\\",
#         'subject': "CE17_18_07_19_000003",
#         'dataType': 'VHDR',
#         'emispheric_stimulation': 'CX',
#     })
#
# elif sub == 'UNIMI':
#     json_data.update({
#         'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\\",
#         'subject': "prova_Mario_0003",
#         'dataType': 'VHDR',
#         'emispheric_stimulation': 'CX',
#     })

# %% [markdown]
# # init

# %%
json_data, experiment_dir, sub = directorySetup(json_data)

# %% [markdown]
# # load_and_prepare_raw_data

# %%
raw, events, json_data = load_and_prepare_raw_data(
    json_data=json_data,
    fileName=fileName,
    experiment_dir=experiment_dir,
    sub=sub
)
# Out:
# Extracting parameters from E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\\prova_Mario_0003.vhdr...
# Setting channel info structure...
# Reading 0 ... 2771099  =      0.000 ...   554.220 secs...

# %% [markdown]
# # computeBasicSteps

# %%
raw_cleaned, epochs, detrendedEpochs, temp_epochs, json_data = computeBasicSteps(
    raw, events, json_data, experiment_dir, sub, computeFOOOF=False
)
# Out:
# 🔧 [prova_Mario_0003] Step 1: Rimozione artefatto TMS + PSD
# 📉 Plotting PSD before pulse removal...
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.410 (s)
# Plotting power spectral density (dB=True).
# ⚡ Removing TMS pulse artifact...
# 📉 Plotting PSD after pulse removal...
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.410 (s)
# Plotting power spectral density (dB=True).
# 🔧 [prova_Mario_0003] Step 2: Filtro broad-band e notch
# DO-BROADBAND------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 2.5e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 250.00 Hz: -6.02, -6.02 dB
#
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.410 (s)
# Plotting power spectral density (dB=True).
# DO-NOTCH------------------------------------
# DO-NOTCH------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 33001 samples (6.600 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.8s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.410 (s)
# Plotting power spectral density (dB=True).
# [INFO] Raw filtered and saved → E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\20250729175232_T_F_nowind_biexp_nowind_biexp\6.pkls\prova_Mario_0003_raw.pkl
# 🔧 [prova_Mario_0003] Step 3: Pulizia epoche e canali artefattati
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 45.00 Hz: -6.02, -6.02 dB
#
# Not setting metadata
# 200 matching events found
# Setting baseline interval to [-0.1, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 200 events and 2501 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 🤖 Automatic artifact rejection
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 🔧 [prova_Mario_0003] Step 4: Creazione oggetto Epochs finale
# Not setting metadata
# 200 matching events found
# Setting baseline interval to [-0.1, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 200 events and 2501 original time points ...
# 0 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# ✅ [prova_Mario_0003] Completato. Informazioni finali su Epochs:
# <Info | 10 non-empty values
#  bads: 3 items (CP2, FC2, Fpz)
#  ch_names: Oz, PO4, PO3, P6, P4, Pz, P3, P5, TP10, CP6, CP2, CP1, CP5, TP9, ...
#  chs: 31 EEG
#  custom_ref_applied: True
#  dig: 34 items (3 Cardinal, 31 EEG)
#  highpass: 0.1 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2024-12-17 15:58:28 UTC
#  nchan: 31
#  projs: []
#  sfreq: 1024.0 Hz
# >
#
# 🔍 [prova_Mario_0003] Step 1: Verifica della necessità di detrending...
#
# 🔍 [prova_Mario_0003] Step 1: analisi delle latenze offset
# Processing channels: 100%|█████████████████████████████████████████████████████████████| 31/31 [00:02<00:00, 13.37it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:18<00:00,  1.64it/s]
# 📉 [prova_Mario_0003] Step 2: Calcolo delle pendenze (computeSlopes_v4)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:06<00:00,  4.73it/s]
# 📊 [prova_Mario_0003] Step 3: Plot delle pendenze normalizzate (Zslope)
# p_value 0.0 F 4467.791409355549
# 📈 [prova_Mario_0003] Step 4: Calcolo media Zslope per canale e finestra
#
# 📌 [prova_Mario_0003] Risultati:
#    • Zslope threshold = 0.5
#    • Canali oltre soglia (2): ['C3', 'Cz']
#    • do_detrend = True
#
# 🧼 [prova_Mario_0003] Step 2: Esecuzione del pipeline di detrending sui canali selezionati...
# I am doing nowind_biexp detrend
# ###
# 360
# p plot 0.027777777777777776
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [01:40<00:00,  3.23s/it]
# Not setting metadata
# 180 matching events found
# No baseline correction applied
# 0 projection items activated
# [INFO] Salvato tabStat in: E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\\20250729175232_T_F_nowind_biexp_nowind_biexp\2.detrend\tabStatDetrend_nowind_biexp.csv
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:06<00:00,  4.58it/s]
# p_value 3.8209772937404594e-138 F 430.6076306949099
# 🔧 Applico notch IIR a canali offset ['C3', 'Cz'] su frequenze: [50, 100, 150, 200, 250]
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
#
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
#
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
#
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# ✅ [prova_Mario_0003] Detrending completato.
#
#
# 🔍 [prova_Mario_0003] Step 3: Compute FOOOF

# %% [markdown]
# # ICAprocessing

# %%
if json_data['do_ica']:
    dataToICA = detrendedEpochs if json_data['detrend_overall'] else epochs
    postICA_final, json_data = ICAprocessing(
        dataToICA,
        json_data, experiment_dir, sub,
        manualCheck=json_data['do_ica_manualCheck'],
        computeFOOOF=False
    )

    json_data = computeFeatExtraction_v2(postICA_final, json_data, experiment_dir, sub)
    json_data = saveLoadTestFinal(postICA_final, json_data, experiment_dir, sub, start_time)
