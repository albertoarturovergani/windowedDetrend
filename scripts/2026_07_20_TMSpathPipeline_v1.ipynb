# %% [markdown]
# # pars

# %%
from tmspath_utils import *

# %%
date, start_time = import_modules()

detrendType = 'Windowed' #'Windowed'  #'Non-Windowed' #'ICA_Detrend' '

if detrendType == 'Non-Windowed':
    typeOffsetRise, typeOffsetDecay = 'nowind_biexp', 'nowind_biexp'
if detrendType == 'Windowed':
    typeOffsetRise = 'wind_poly_lagrange' #'wind_poly_lagrange' #wind_poly_lagrange' #'wind_singlerise',
    typeOffsetDecay = 'wind_poly_3' #'wind_poly_3' # 'wind_poly_0', 'wind_poly_1', 'wind_poly_2', 'wind_singledecay',
if detrendType == 'ICA_Detrend':
    typeOffsetRise = 'ICA' 
    typeOffsetDecay = 'ICA' 
    
# === Config iniziale ===
json_data = {
    # utils
    'date': date,
    'start_time': start_time,
    'do_filter_and_plot_raw': True,
    'showPlotsEnd': False,
    'r_sfreq': 1024,
    'eeg_type': 'tep',

    # filtering, 
    'l_freq': 0.1, #1.59,
    'h_freq': 45,
    'powerline_freq': 50,
    'broad_band_h_freq': 250,

     # stimulation
    'do_pulseArtifactRej': True,
    'pulse_artifact_rej_timewindow_min' : -0.002, 
    'pulse_artifact_rej_timewindow_max' : 0.008,  
    'emispheric_stimulation': 'SX',
    'seedChans': ['AF3', 'F3', 'Fz', 'FC1'],
    
     # epoching
    'do_prepare_epochs': True,
    'epochs_timewindow_min': -0.1,
    'epochs_timewindow_max': 0.4,
    'baseline_cor_tmin': -0.15,
    'baseline_cor_tmax': 0,
    
     # chans and trials cleaning
    'do_clean_trials_channels': True,
    'do_chan_trials_selection_automatic': False, # if you do True, PARS are in tmspath_utils.py ctrl-f AUTOCHANTRIALSREJ
    'bad_trials': [], # np.arange(0,180).tolist(), #[100], #[13,37,44,51,55], # [] else leave empty
    'bad_channels': [], # ['AF3'], # [] else leave empty
     # nota: nella visualizzazione manuale, i bad trials e bad channels pre-indicated non sono visualizzati 
     # ma sono tolti in automatatico successivamente
    
     # injected artifacts options
    'do_artifact': False, 
    'do_artifact_rise': 0.005,
    'do_artifact_decay': 0.1,
    'do_artifact_gain': -3e-6 * 30,
    'do_artifact_chans': ['Cz'],

     # ica options
    'do_ica': True, # if typeOffsetDecay == typeOffsetRise == 'ICA' make True else no detrend at all
    'do_ica_continuum': False,
    'do_ica_manualCheck': True, 
    'do_ica_eigThresh': 0,
    'do_ica_automaticRej': False if detrendType == 'ICA_Detrend' else True, # è messo in falso nel caso di detrend con ICA per permettere all'operatore di valutare quali sono le componenti offset che IClabel non può conoscere
    'do_label_prob_threshold': 0,

     # detrend options
    'trials_wise': True,  # True: detrend su ogni trial; False: detrend sulla media (TEP)
    'detrendExtremeTechinque': 'max',
    'detrend_type': typeOffsetDecay,
    'do_detrend': typeOffsetDecay != 'ICA', # if FALSE it acts with detrend_overall if True, else no detrend at all
    'do_detrend_onlyOffsetChans': False,
    'detrend_offsetStart': True,
    'detrend_lag_correction': False,
    'detrend_typeOffsetRise': typeOffsetRise,
    'detrend_typeOffsetDecay': typeOffsetDecay,
    'detrend_polOrder_preOffset': 2,
    'detrend_slopeThr': 0.5, # 0.5, important for making the detrend otherwise skip to poly0 without windowing (demeaning)
    'detrend_offsetCorrectionType': 'Gaussian' if 'nowind' not in typeOffsetDecay else False,
    'detrend_offsetOddSamples': 5,
    'detrend_overall': True,
    'detrend_noWindowedOrder': 1, # if detrend_overall True, it uses an overall linear detrend (if 0, is a constant (signal mean), not a line))
    'detrend_maxTimeWindowOffset': 0.020,
    'detrend_minTimeWindowOffset': 0.0,
    'detrend_fitConstraint': False if 'nowind' not in typeOffsetDecay else True,

    # directory and subject
    #'experiment_dir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\TEP_PP\PP032\\ESAME 1\\TEST",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\1.Easycap+Brainamp+Nexstim\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\2.Easycap+Brainamp+EBNeuro_stim\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\3.Easycap+EBNeuro_amp+EBNeuro_stim\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\4.Easycap+EBNeuro_amp+Nexstim\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\MI_EXP\5.EBNeuro_cap+Brainamp+Nexstim\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\Chalfont\CE20_07_08_2019_Session_4_LPrem_77\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\Chalfont\CE17_18_07_2019_Session_3_RMot_41\\",
    #'mainDir': r"E:\Nuova cartella\OneDrive - Scuola Superiore Sant'Anna\dellXXX-laptop\temp_SSSP\PROJECTS\TMSPATH\DATI\TEP_PP\PP007\\",
    
    # RICORDARSI DI METTERE PATH ASSOLUTO!
    'mainDir': r"C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2/",
    'sourceData': 'MAYER', #'UNIMI', # MAYER CHALFONT
    'subject': "CV017", #"CE17_18_07_19_000003", #"CE20_07_08_2019_000004" , "CE17_18_07_19_000003" "prova_Mario_0003", #"prova_Betta_0002", #"prova_Mario_0003", #"TEPEMISFEROSXSTIMNETXTIMEASYCUP", #"prova_Betta_0002", #'TEPEMISFEROSXEASYCUP', #"prova_Betta_0002", #"prova_Betta_0001", #"prova_Mario_0003",  #prova_Mario_0003", #"CE20_07_08_2019_000004", #"prova_Mario_0003",
    'dataType': 'ASCII', #'VHDR', #'ASCII', #'VHDR',
    'emispheric_stimulation': 'SX',
    # 'seedChans': ['AF3', 'F3', 'Fz', 'FC1'], #'SX': ['AF3', 'F3', 'Fz', 'FC1'], 'DX': ['Fz', 'AF4', 'F4', 'FC2'],
}
if json_data['emispheric_stimulation'] == 'SX':
    json_data['seedChans'] = ['AF3', 'F3', 'Fz', 'FC1']

elif json_data['emispheric_stimulation'] == 'DX':
    json_data['seedChans'] = ['Fz', 'AF4', 'F4', 'FC2']

mainDir = json_data['mainDir']
subject = json_data['subject']
experiment_dir_ = f'{mainDir}{subject}'
fileName = f'{mainDir}{subject}/{json_data['emispheric_stimulation']}/{json_data['subject']}_emisfero_{json_data['emispheric_stimulation']}'
savePath = f'{mainDir}{subject}'
json_data['analysis_id'] = f'{date}_{subject}'

print(fileName)
# Out:
# C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2/CV017/SX/CV017_emisfero_SX

# %% [markdown]
# # TMS-EEG Processing Pipeline
#
# ### 1. Preprocessing & Artifact Removal
# 1. **Load EEG**
# 2. **Apply montage**
# 3. **Detect TMS events**
# 4. **Remove TMS pulse artifact**
# 5. **Broad-band filter** (0.1–250 Hz)
# 6. **Notch filter** (50 / 100 / 150 / 200 / 250 Hz)
#
# ---
#
# ### 2. Preliminary Cleaning
# 7. **Create long temporary epochs** (for cleaning)
# 8. **Temporary average reference**
# 9. **Automatic / manual trial and channel rejection**
#
# ---
#
# ### 3. Epoching & Detrending
# 10. **Create final epochs** (-100 to +400 ms)
# 11. **Downsample** (to 1024 Hz)
# 12. **Average reference**
# 13. *Optional:* **Pre-detrend PSD / FOOOF**
# 14. **Slope and offset analysis**
# 15. **Selected detrending strategy**
#
# ---
#
# ### 4. Component Analysis & Finalizing
# 16. **ICA** (Independent Component Analysis)
# 17. **Final filter** (0.1–45 Hz)
# 18. **Upsample** (to original sampling rate)
# 19. **Interpolate bad channels**
# 20. **Save** `postICA_final` and final plots

# %% [markdown]
# # init

# %%
json_data, experiment_dir, sub = directorySetup(json_data)
# Out:
# 📁 Generated experiment_dir: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2/20260720171449_T_F_nowind_biexp_nowind_biexp

# %%
experiment_dir
# Out:
# "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\testPipelinesV1V2/20260720171449_T_F_nowind_biexp_nowind_biexp"

# %% [markdown]
# # load_and_prepare_raw_data

# %%
raw, events, json_data = load_and_prepare_raw_data(
    json_data=json_data,
    fileName=fileName,
    experiment_dir=experiment_dir,
    sub=sub
)
# Out:
# 📁 Generated experiment_dir: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2/20260720171449_T_F_nowind_biexp_nowind_biexp
# GALNT ASCII CONVERTED FILE"
#
# Patient Data: " "SOFIA TEST" "19/09/1995"
#
# Trace date: " "02/07/2024"
#
# Start second: " 0
#
# Seconds: " 449
#
# Sampling rate : " 4096
#
# Values are expressed in [uV]"
#
# TR 00", "TR 01", "TR 02", "TR 03", "TR 04", "TR 05", "TR 06", "TR 07", "TR 08", "TR 09", "TR 10", "TR 11", "TR 12", "TR 13", "TR 14", "TR 15", "TR 16", "TR 17", "TR 18", "TR 19", "TR 20", "TR 21", "TR 22", "TR 23", "TR 24", "TR 25", "TR 26", "TR 27", "TR 28", "TR 29", "TR 30", "TR 31", "TR 32"
#
# ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'FPz', 'CP1', 'CP2', 'CP5', 'CP6', 'TM', 'MK']
# Il canale MK è presente nel DataFrame.
# Il canale EMG non è presente nel DataFrame.
# Il canale TM è presente nel DataFrame.
# Esperimento ha durata time=449.0 con sr=4096.0 e samples=1839104
# Extracting EDF parameters from C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2\CV017\SX\CV017_emisfero_SX.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1839103  =      0.000 ...   449.000 secs...
# Il canale 'EMG' non è presente.
# ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'Fpz', 'CP1', 'CP2', 'CP5', 'CP6']

# %% [markdown]
# # computeBasicSteps

# %%
raw_cleaned, epochs, detrendedEpochs, temp_epochs, json_data = computeBasicSteps(
    raw, events, json_data, experiment_dir, sub, computeFOOOF=False
)
# Out:
# 🔧 [CV017] Step 1: Rimozione artefatto TMS + PSD
# 📉 Plotting PSD before pulse removal...
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# ⚡ Removing TMS pulse artifact...
# 📉 Plotting PSD after pulse removal...
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# 🔧 [CV017] Step 2: Filtro broad-band e notch
# DO-BROADBAND------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 2.5e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 250.00 Hz: -6.02, -6.02 dB
#
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# DO-NOTCH------------------------------------
# DO-NOTCH------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 27035 samples (6.600 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    2.5s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# [INFO] Raw filtered and saved → C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2\20260720171449_T_F_nowind_biexp_nowind_biexp\6.pkls\CV017_raw.pkl
# 🔧 [CV017] Step 3: Pulizia epoche e canali artefattati
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 45.00 Hz: -6.02, -6.02 dB
#
# Not setting metadata
# 170 matching events found
# Setting baseline interval to [-0.800048828125, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 170 events and 36046 original time points ...
# 2 bad epochs dropped
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# 🤖 Automatic artifact rejection
# 🧹 Dropping automatic bad channels: ['AF4', 'CP1', 'Fpz']
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# ✅ clean_trials_channels completed
#    Trials kept: 150 / 168
#    Channels kept: 28 / 31
#    Dropped channels: ['AF4', 'CP1', 'Fpz']
# 🔧 [CV017] Step 4: Creazione oggetto Epochs finale
# Not setting metadata
# 170 matching events found
# Setting baseline interval to [-0.10009765625, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 170 events and 2049 original time points ...
# 0 bad epochs dropped
# 🧹 Dropping bad channels also from final epochs: ['AF4', 'CP1', 'Fpz']
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# ✅ prepare_epochs completed
#    Final trials: 150
#    Final channels: 28
#    Final channel names: ['AF3', 'FC1', 'FC2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'CP2', 'CP5', 'CP6']
# ✅ [CV017] Completato. Informazioni finali su Epochs:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: AF3, FC1, FC2, F7, F3, Fz, F4, F8, FC5, T3, C3, Cz, C4, T4, FC6, ...
#  chs: 28 EEG
#  custom_ref_applied: True
#  dig: 34 items (3 Cardinal, 31 EEG)
#  highpass: 1.6 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2024-07-02 11:06:20 UTC
#  nchan: 28
#  projs: []
#  sfreq: 1024.0 Hz
#  subject_info: 5 items (dict)
# >
#
# 🔍 [CV017] Step 1: Verifica della necessità di detrending...
#
# 🔍 [CV017] Step 1: analisi delle latenze offset
# Processing channels: 100%|█████████████████████████████████████████████████████████████| 28/28 [00:02<00:00, 13.53it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:37<00:00,  1.35s/it]
# 📉 [CV017] Step 2: Calcolo delle pendenze (computeSlopes_v4)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:10<00:00,  2.61it/s]
# 📊 [CV017] Step 3: Plot delle pendenze normalizzate (Zslope)
# p_value nan F nan
# 📈 [CV017] Step 4: Calcolo media Zslope per canale e finestra
#
# 📌 [CV017] Risultati:
#    • Zslope threshold = 0.5
#    • Canali oltre soglia (2): ['F3', 'Fz']
#    • do_detrend = True
#
# 🧼 [CV017] Step 2: Esecuzione del pipeline di detrending sui canali selezionati...
# --- Mode: TRIALS-WISE (Processing all individual trials) ---
# epochs_to_process data shape: (150, 28, 512)
# epochs_to_process times len: 512
# I am doing nowind_biexp detrend
# ###
# 300
# p plot 0.03333333333333333
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [05:13<00:00, 11.19s/it]
# INPUT data shape: (150, 28, 512)
# INPUT times len: 512
# DETRENDED data shape: (150, 28, 512)
# DETRENDED times len: 512
# [INFO] Salvato tabStat in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2/20260720171449_T_F_nowind_biexp_nowind_biexp\2.detrend\tabStatDetrend_nowind_biexp.csv
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [00:11<00:00,  2.53it/s]
# p_value nan F nan
# 🔧 Applico notch IIR a canali offset ['F3', 'Fz'] su frequenze: [50, 100, 150, 200, 250]
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
#
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.1s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# ✅ [CV017] Detrending completato.
#
#
# 🔍 [CV017] Step 3: Compute FOOOF

# %% [markdown]
# # ICAprocessing

# %%
if json_data['do_ica']:
    dataToICA = detrendedEpochs if json_data['detrend_overall'] else epochs
    postICA_final, json_data = ICAprocessing(
        dataToICA,
        json_data, experiment_dir, sub,
        autoReject=json_data['do_ica_automaticRej'],
        manualCheck=json_data['do_ica_manualCheck'],
        computeFOOOF=False
    )
    
    do_run_gif=True
    if do_run_gif:
        from pathlib import Path
        postica_subpath = Path("4.postICA") / json_data["ICA_timestamp"]   
        gif_path, json_data = create_butterfly_topomap_gif(
            epochs=postICA_final,
            json_data=json_data,
            experiment_dir=experiment_dir,
            sub=sub,
            saveNote="postICA_final",
            subPath=str(postica_subpath),
            tmin=-0.1,
            tmax=0.45,
            step=0.002,
            xlim=(-0.1, 0.45),
            vlim=(-5, 5),   # Volt
            sphere=0.095,
            duration=50,
            transparency=False,
            save_static=True
        )
        print(gif_path)
        
    json_data = saveLoadTestFinal(postICA_final, json_data, experiment_dir, sub, start_time)
# Out:
# ⚙️ ICA eigThresh = 0, label_prob_threshold = 0
# [INFO] Oggetto passato direttamente
# Fitting ICA to data using 28 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 28 components
# Fitting ICA took 9.6s.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✅ IC 0: brain (prob: 0.95) – mantenuto automaticamente
# ❌ IC 2: eye blink (prob: 0.49) – escluso automaticamente
# ✅ IC 2: brain (prob: 1.00) – mantenuto automaticamente
# ❌ IC 4: muscle artifact (prob: 0.92) – escluso automaticamente
# ❌ IC 5: eye blink (prob: 1.00) – escluso automaticamente
# ✅ IC 5: brain (prob: 0.85) – mantenuto automaticamente
# ❌ IC 7: other (prob: 0.40) – escluso automaticamente
# ❌ IC 8: other (prob: 0.54) – escluso automaticamente
# ✅ IC 8: brain (prob: 0.93) – mantenuto automaticamente
# ✅ IC 9: brain (prob: 0.99) – mantenuto automaticamente
# ❌ IC 11: other (prob: 0.76) – escluso automaticamente
# ✅ IC 11: brain (prob: 0.90) – mantenuto automaticamente
# ✅ IC 12: brain (prob: 1.00) – mantenuto automaticamente
# ✅ IC 13: brain (prob: 0.86) – mantenuto automaticamente
# ✅ IC 14: brain (prob: 0.62) – mantenuto automaticamente
# ❌ IC 16: eye blink (prob: 0.34) – escluso automaticamente
# ✅ IC 16: brain (prob: 0.87) – mantenuto automaticamente
# ✅ IC 17: brain (prob: 0.59) – mantenuto automaticamente
# ❌ IC 19: eye blink (prob: 0.43) – escluso automaticamente
# ❌ IC 20: muscle artifact (prob: 0.64) – escluso automaticamente
# ✅ IC 20: brain (prob: 0.88) – mantenuto automaticamente
# ✅ IC 21: brain (prob: 0.73) – mantenuto automaticamente
# ✅ IC 22: brain (prob: 0.71) – mantenuto automaticamente
# ✅ IC 23: brain (prob: 0.68) – mantenuto automaticamente
# ❌ IC 25: other (prob: 0.74) – escluso automaticamente
# ✅ IC 25: brain (prob: 0.57) – mantenuto automaticamente
# ✅ IC 26: brain (prob: 0.86) – mantenuto automaticamente
# ❌ IC 28: eye blink (prob: 0.55) – escluso automaticamente
# [Auto-tagging] Componenti escluse per ICLabel: [1, 3, 4, 6, 7, 10, 15, 18, 19, 24, 27]
# [Autovalori] Componenti escluse eigenvalue <= 0.0444: [27]
# 🖱️ Manual ICA check. Componenti pre-marcate: [1, 3, 4, 6, 7, 10, 15, 18, 19, 24, 27]
# Running ICApp...
# Applying baseline correction (mode: mean)
# 📌 ICA initial excluded: [1, 3, 4, 6, 7, 10, 15, 18, 19, 24, 27]
# 📌 ICA final excluded:   [1, 3, 4, 6, 7, 10, 14, 15, 16, 17, 18, 19, 20, 22, 24, 27]
# 📌 ICA manual added:     [14, 16, 17, 20, 22]
# 📌 ICA manual recovered: []
# Applying ICA to Epochs instance
#     Transforming to ICA space (28 components)
#     Zeroing out 16 ICA components
#     Projecting back using 28 PCA components
# Setting up band-pass filter from 0.1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 33793 samples (33.001 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=1)]: Done 881 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=1)]: Done 1151 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=1)]: Done 1457 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=1)]: Done 1799 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=1)]: Done 2177 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=1)]: Done 2591 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=1)]: Done 3041 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=1)]: Done 3527 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=1)]: Done 4049 tasks      | elapsed:   12.3s
# Setting channel interpolation method to {'eeg': 'spline'}.
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# 2026-07-20 17:28:53,784 - matplotlib.animation - WARNING - MovieWriter ffmpeg unavailable; using Pillow instead.
# 2026-07-20 17:28:53,784 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.PillowWriter'>
# Video salvato in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2/20260720171449_T_F_nowind_biexp_nowind_biexp\4.postICA\20260720172544/CV017_scalpmaptime_postICA.gif
# ✅ GIF salvata: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2\20260720171449_T_F_nowind_biexp_nowind_biexp\4.postICA\20260720172544\CV017_postICA_final_butterfly_topomap_opaque.gif
# C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\testPipelinesV1V2\20260720171449_T_F_nowind_biexp_nowind_biexp\4.postICA\20260720172544\CV017_postICA_final_butterfly_topomap_opaque.gif
# QFileDialog
# make_standard_montage
# label_components
# PrepPipeline
# NoisyChannels
# datetime
# euclidean
# Path
# interp1d
# resample
# expon
# gamma
# laplace
# linregress
# norm
# poisson
# rayleigh
# t
# uniform
# ARIMA
# FuncAnimation
# tabulate
# tqdm
# notebook_tqdm
# create_info
# EvokedArray
# RawArray
# FOOOF
# gen_power_spectrum
# set_random_seed
# plot_spectra
# plot_annotated_model
# import_modules
# make_json_serializable
# directorySetup
# directorySetup_old_20260416
# loadEDF
# loadASCII
# computeDetrendSteps
# add_exp_artifact
# computeBasicSteps
# load_and_prepare_raw_data
# run_ica_continuum_pipeline
# remove_tms_artifact_and_plot_psd
# filter_and_plot_raw
# clean_trials_channels
# clean_trials_channels_old_20260416
# clean_trials_channels_20260415
# apply_notch_to_offsetChans
# run_detrend_pipeline
# notch_filter_offset_chans
# apply_notch_filter
# prepare_epochs
# analyze_offset_times
# check_detrend_need
# add_TEP_to_json
# ICAprocessing
# ICAprocessing_old_20260416
# computeFeatExtraction
# computeFeatExtraction_v2
# plot_TEP_1d_with_shading
# saveLoadTestFinal
# saveLoadTestFinal_old_20260416
# selectTEPfeat
# set_plot_params
# FIGSIZE
# shift_signal_by_mask
# polyfit_constrained_start
# compute_condition_number_epochs_average
# run_ica_filtering_v3
# run_ica_filtering_v3_old_20260416
# postICAsteps
# plot_ersp
# plot_topomap
# plot_gmfp
# find_outlier_channels_by_twindow_v2
# find_outlier_channels_by_twindow
# find_outlier_channels_by_twindow_v3
# run_ica_filtering
# run_ica_filtering_v2
# run_ica_artist_ext_only
# run_ica_artist_tms_events
# plot_customTEP
# basicPlots
# create_butterfly_topomap_gif
# runICA
# welch
# filter_data
# extract_psd_features
# save_bad_epochs_and_channels
# plotTrialTepVariability
# computeTimeMasks
# computeTimeMasks_old16102025
# computeTimeMasks_old15102025
# computeTimeMasks_old
# computeSlopes_v4
# computeSlopes_v4_old
# computeSlopesPlot_v3
# computeSlopesPlot_v2
# computeSlopesPlot
# generate_noise_from_distribution
# generate_noise_from_distribution_old151012025
# supported_models
# computeDetrend_v6
# plot_detrend_example_v3
# plot_detrend_example
# plot_tabStat
# apply_offset_correction
# apply_offset_correction_old15102025
# plot_slope_resonances
# ✅ Tempo totale di esecuzione: 1052.23 secondi
